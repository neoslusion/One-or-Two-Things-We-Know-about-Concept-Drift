# %% [markdown]
# # Evaluation Notebook
# Load `artifacts/final_report.json`, visualize prequential accuracy over time, and compute MTTD/TP/FP/FN.

# %%
import json, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path
r = json.load(open('artifacts/final_report.json'))
r
